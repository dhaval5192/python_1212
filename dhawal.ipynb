# %%
import pandas as pd

# %%
# df2 =pd.DataFrame({'Srno': [1,2,3,4,5], 'Name' :['a','b','c','d','e']}, index=[1,2,3,4,5])

# %%
# df2
# Out:
#    Srno Name
# 1     1    a
# 2     2    b
# 3     3    c
# 4     4    d
# 5     5    e

# %%
# df2.iloc[0,1]

# %%
df = pd.read_csv('Sales_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       125 non-null    int64
#  1   OrderDate     125 non-null    str
#  2   Region        124 non-null    str
#  3   CustomerType  124 non-null    str
#  4   Category      124 non-null    str
#  5   Product       124 non-null    str
#  6   Quantity      124 non-null    float64
#  7   UnitPrice     124 non-null    str
#  8   Discount      124 non-null    str
#  9   Returned      124 non-null    str
# dtypes: float64(1), int64(1), str(8)
# memory usage: 9.9 KB

# %%
df['Discount']=df['Discount'].astype
